# %%
from src.aws_data_ingestion import DataIngestion
from src.logger import get_logger
from utils.common_functions import load_config
import os
os.getcwd()
# Out:
# 'c:\\Users\\sachi\\Projects\\PythonProjects\\Learn_MLOps_Application\\Project-2'

# %%
logger = get_logger()
config = load_config("config/config.yaml")

# %%
ingestion=DataIngestion(config=config, logger=logger)

# %%
ingestion.upload()
# Out:
# {'bucket': 'mlops-project-data-251130',
#  'key': 'hotel_reservation/hotel_reservations.csv'}
